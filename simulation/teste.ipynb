# %%
from epyt import epanet

# %%
network = epanet('net3.inp')
# Out:
# EPANET version 20200 loaded (EPyT version v1.2.2 - Last Update: 10/05/2025).
# Input File net3.inp loaded successfully.

# %%
# network.getAdjacencyMatrix()
teste = network.getNodeNameID()

teste.sort()

teste
# Out:
# ['1',
#  '10',
#  '101',
#  '103',
#  '105',
#  '107',
#  '109',
#  '111',
#  '113',
#  '115',
#  '117',
#  '119',
#  '120',
#  '121',
#  '123',
#  '125',
#  '127',
#  '129',
#  '131',
#  '139',
#  '141',
#  '143',
#  '145',
#  '147',
#  '149',
#  '15',
#  '151',
#  '153',
#  '157',
#  '159',
#  '161',
#  '163',
#  '164',
#  '166',
#  '167',
#  '169',
#  '171',
#  '173',
#  '177',
#  '179',
#  '181',
#  '183',
#  '184',
#  '185',
#  '187',
#  '189',
#  '191',
#  '193',
#  '195',
#  '197',
#  '199',
#  '2',
#  '20',
#  '201',
#  '203',
#  '204',
#  '205',
#  '206',
#  '207',
#  '208',
#  '209',
#  '211',
#  '213',
#  '215',
#  '217',
#  '219',
#  '225',
#  '229',
#  '231',
#  '237',
#  '239',
#  '241',
#  '243',
#  '247',
#  '249',
#  '251',
#  '253',
#  '255',
#  '257',
#  '259',
#  '261',
#  '263',
#  '265',
#  '267',
#  '269',
#  '271',
#  '273',
#  '275',
#  '3',
#  '35',
#  '40',
#  '50',
#  '60',
#  '601',
#  '61',
#  'Lake',
#  'River']
